# %% [markdown]
# <a href="https://colab.research.google.com/github/Sidhtang/machine-learining-with-CN/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sample_text="does this thing really works?,lets see"

# %%
from nltk.tokenize import sent_tokenize , word_tokenize

# %%
 import nltk
 nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent_tokenize(sample_text)
# Out:
# ['does this thing really works?,lets see']

# %%
 words= word_tokenize(sample_text)

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop= stopwords.words("english")
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import string
punctuations= list(string.punctuation)
stop = stop + punctuations

# %%
clean_words= [w for w in words if not w in stop]
clean_words
# Out:
# ['thing', 'really', 'works', 'lets', 'see']

# %%
#stemming different words(getting to the root word)

# %%
from nltk.stem import PorterStemmer

# %%
stem_words=["play,player,played,playing"]
ps= PorterStemmer()
stemmed_words= [ps.stem(w) for w in stem_words]
stemmed_words
# Out:
# ['play,player,played,play']

# %%
#finding part of speech

# %%
from nltk import pos_tag

# %%
from nltk.corpus import state_union

# %%
import nltk
nltk.download('state_union')
# Out:
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.
# True

# %%
text= state_union.raw("2006-GWBush.txt")
text
# Out:
# 'PRESIDENT GEORGE W. BUSH\'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all. Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream. Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King. (Applause.)\n\nPresident George W. Bush reacts to applause during his State of the Union Address at the Capitol, Tuesday, Jan. 31, 2006. White House photo by Eric DraperEvery time I\'m invited to this rostrum, I\'m humbled by the privilege, and mindful of the history we\'ve seen together. We have gathered under this Capitol dome in moments of national mourning and national achievement. We have se
# ...

# %%
 import nltk
 nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos= pos_tag(word_tokenize(text))
pos
# Out:
# [('PRESIDENT', 'NNP'),
#  ('GEORGE', 'NNP'),
#  ('W.', 'NNP'),
#  ('BUSH', 'NNP'),
#  ("'S", 'POS'),
#  ('ADDRESS', 'NNP'),
#  ('BEFORE', 'IN'),
#  ('A', 'NNP'),
#  ('JOINT', 'NNP'),
#  ('SESSION', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('CONGRESS', 'NNP'),
#  ('ON', 'NNP'),
#  ('THE', 'NNP'),
#  ('STATE', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('UNION', 'NNP'),
#  ('January', 'NNP'),
#  ('31', 'CD'),
#  (',', ','),
#  ('2006', 'CD'),
#  ('THE', 'NNP'),
#  ('PRESIDENT', 'NNP'),
#  (':', ':'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('all', 'DT'),
#  ('.', '.'),
#  ('Mr.', 'NNP'),
#  ('Speaker', 'NNP'),
#  (',', ','),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('Cheney', 'NNP'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('Congress', 'NNP'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Supreme', 'NNP'),
#  ('Court', 'NNP'),
#  ('and', 'CC'),
#  ('diplomatic', 'JJ'),
#  ('corps', 'NN'),
#  (',', ','),
# ...

# %%
#LEMMATIZTION

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
 import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer.lemmatize("better", pos= "a")
# Out:
# 'good'

# %%
from nltk.corpus import movie_reviews

# %%
import nltk
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
movie_reviews.fileids()
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt',
#  'neg/cv005_29357.txt',
#  'neg/cv006_17022.txt',
#  'neg/cv007_4992.txt',
#  'neg/cv008_29326.txt',
#  'neg/cv009_29417.txt',
#  'neg/cv010_29063.txt',
#  'neg/cv011_13044.txt',
#  'neg/cv012_29411.txt',
#  'neg/cv013_10494.txt',
#  'neg/cv014_15600.txt',
#  'neg/cv015_29356.txt',
#  'neg/cv016_4348.txt',
#  'neg/cv017_23487.txt',
#  'neg/cv018_21672.txt',
#  'neg/cv019_16117.txt',
#  'neg/cv020_9234.txt',
#  'neg/cv021_17313.txt',
#  'neg/cv022_14227.txt',
#  'neg/cv023_13847.txt',
#  'neg/cv024_7033.txt',
#  'neg/cv025_29825.txt',
#  'neg/cv026_29229.txt',
#  'neg/cv027_26270.txt',
#  'neg/cv028_26964.txt',
#  'neg/cv029_19943.txt',
#  'neg/cv030_22893.txt',
#  'neg/cv031_19540.txt',
#  'neg/cv032_23718.txt',
#  'neg/cv033_25680.txt',
#  'neg/cv034_29446.txt',
#  'neg/cv035_3343.txt',
#  'neg/cv036_18385.txt',
#  'neg/cv037_19798.txt',
# ...

# %%
documents = []
for category in movie_reviews.categories():
    for field in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(field), category))
        documents[0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-49d668f1e765> in <cell line: 2>()
#       1 documents = []
# ----> 2 for category in movie_reviews.categories():
#       3     for field in movie_reviews.fileids(category):
#       4         documents.append((movie_reviews.words(field), category))
#       5         documents[0:5]
#
# NameError: name 'movie_reviews' is not defined

# %%
import random
random.shuffle(documents)
documents[0:5]
# Out:
# []

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer= WordNetLemmatizer

# %%
from nltk.corpus import wordnet

def get_simple_pos(tag):
    if tag.startswith("J"):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
import string
stops= set(stopwords.words("english"))
punctuations= list(string.punctuation)
stops.update(punctuations)
stops
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
# ...

# %%
def clean_review(words):
  output_words=[]
  for w in words:
    if w.lower() not in stops:
      pos= pos_tag(w)
      clean_word  = lemmatizer.lemmatize(w,pos= get_simple_pos(pos[0][1]))
      output_words.append(clean_word.lower())
      return output_words

# %%
documents = [(clean_review(document), category) for document, category in documents]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c7b639d350a3> in <cell line: 1>()
# ----> 1 documents = [(clean_review(document), category) for document, category in documents]
#
# NameError: name 'documents' is not defined

# %%
training_documents= documents[0:1500]
testing_documents= documents[1500:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0c50d7965e47> in <cell line: 1>()
# ----> 1 training_documents= documents[0:1500]
#       2 testing_documents= documents[1500:]
#
# NameError: name 'documents' is not defined

# %%
 all_words=[]
 for doc in training_documents:
all_words += doc[0]
# Out:
#   File "<ipython-input-11-21ad4c40d1f4>", line 3
#     all_words += doc[0]
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
import nltk

# %%
freq=nltk.FregDist(all_words)
common= freq.most_common(3000)
features= [i[0] for i in common]

# %%
features

# %%
def get_features_dict(words):
  current_features= {}
  word_set = set(words)
for w in features
current_features[w] = w in word_set
return current_features

# %%
training_data=[(get_features_dict(doc),category) for doc ,category in training_documents
# Out:
#   File "<ipython-input-12-e320438d0a4e>", line 1
#     training_data=[(get_features_dict(doc),category) for doc ,category in training_documents
#                                                                                             ^
# SyntaxError: incomplete input

# %%
testing_data=[(get_features_dict(doc),category) for doc ,category in testing_documents

# %%
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(classifier,testing_data)

# %%
##NLP_2

# %%
pip install svc

# %%
from sklearn.svm import svc
from nltk.classify.sckitlearn import SklearnClassifier

# %%
svc = SVC()
classifier_sklearn= SklearnClassifier(svc)

# %%
classifier_sklearn.train(trainig_data)

# %%
nltk.classify.accuracy(classifier_sklearn,testing_data)

# %%
pip install CountVectorizer

# %%
#count vectorizer  use to convert data suitable for nlp

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
train_set = {'the sky is blue', 'the sun is bright'}
count_vec= CountVectorizer(max_features= 3)
a = count_vec.fit_transform(train_set)
a.todense()
# Out:
# matrix([[1, 1, 1],
#         [0, 1, 1]])

# %%
count_vec.get_feature_names()

# %%
categories = [category for document, category in documents]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d0677a250de> in <cell line: 1>()
# ----> 1 categories = [category for document, category in documents]
#
# NameError: name 'documents' is not defined

# %%
text_documents = [" ".join(document) for document, category in documents]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(text_documents, categories)

# %%
count_vec = CountVectorizer(max_features = 2000)
x_train_features = count_vec.fit_transform(x_train)
x_train_features.todense()

# %%
x_test_features = count_vec.transform(x_test)
